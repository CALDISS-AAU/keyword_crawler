# %%
import json
import os
import pandas as pd
from itertools import compress

# %%
datapath = os.path.join('..', 'data')
filepath = os.path.join(datapath, 'drmkc-scrape_20210218.json')

# load data

with open(filepath, 'r') as f:
    data = json.load(f)

# %%
# Functions

def split_urls(entry):
    internals = list(compress(entry['links'], [("drmkc.jrc.ec" in link or "http" not in link) for link in entry['links']]))
    pdfs = list(compress(entry['links'], [(".pdf" in link) for link in entry['links']]))
    externals = list(set(entry['links']) - set(internals))
    
    entry['internals'] = internals
    entry['pdfs'] = pdfs
    entry['externals'] = externals
    
    return(entry)

# %%
for entry in data:
    entry = split_urls(entry)

# %%
df = pd.DataFrame.from_records(data)

# %%
df.head()
# Out:
#                                                  url  \
# 0                    https://drmkc.jrc.ec.europa.eu/
# 1  https://drmkc.jrc.ec.europa.eu/knowledge/Gaps-...
# 2  https://drmkc.jrc.ec.europa.eu/knowledge/PROJE...
# 3  https://drmkc.jrc.ec.europa.eu/knowledge/Chall...
# 4  https://drmkc.jrc.ec.europa.eu/overview/Documents
#
#                                                links date-of-access  \
# 0  [http://drmkc.jrc.ec.europa.eu/Overview/Events...     2021-02-18
# 1  [http://drmkc.jrc.ec.europa.eu/Overview/Events...     2021-02-18
# 2  [http://drmkc.jrc.ec.europa.eu/Overview/Events...     2021-02-18
# 3  [http://drmkc.jrc.ec.europa.eu/Overview/Events...     2021-02-18
# 4  [http://drmkc.jrc.ec.europa.eu/Overview/Events...     2021-02-18
#
#                      keywords_matched  \
# 0  [publicly available, social media]
# 1                      [social media]
# 2                      [social media]
# 3                      [social media]
# 4                      [social media]
#
#                                            internals  \
# 0  [http://drmkc.jrc.ec.europa.eu/Overview/Events...
# 1  [http://drmkc.jrc.ec.europa.eu/Overview/Events...
# 2  [http://drmkc.jrc.ec.europa.eu/Overview/Events...
# 3  [http://drmkc.jrc.ec.europa.eu/Overview/Events...
# 4  [http://drmkc.jrc.ec.europa.eu/Overview/Events...
#
#                                                 pdfs  \
# 0  [/PRIVACY_STATEMENT/Privacy_Statement_DRMKC_We...
# 1  [/PRIVACY_STATEMENT/Privacy_Statement_DRMKC_We...
# 2  [/PRIVACY_STATEMENT/Privacy_Statement_DRMKC_We...
# 3  [/PRIVACY_STATEMENT/Privacy_Statement_DRMKC_We...
# 4  [/PRIVACY_STATEMENT/Privacy_Statement_DRMKC_We...
#
#                                            externals
# 0  [https://ec.europa.eu/jrc/en, https://europa.e...
# 1  [https://ec.europa.eu/jrc/en, https://europa.e...
# 2  [https://www.securityresearch-cou.eu/thethemes...
# 3  [https://ec.europa.eu/jrc/en, https://europa.e...
# 4  [https://ec.europa.eu/jrc/en, https://europa.e...

# %%
# Keywords found

df_kw = df.explode('keywords_matched')
df_kw['keywords_matched'].value_counts()
# Out:
# social media               42
# government                 10
# lidar                       4
# publicly available          3
# applications                2
# agriculture                 2
# participatory               2
# early warning systems       2
# damage assessment           1
# artificial intelligence     1
# situational awareness       1
# drought risk assessment     1
# Name: keywords_matched, dtype: int64

# %%
df_kw.head()
# Out:
#                                                  url  \
# 0                    https://drmkc.jrc.ec.europa.eu/
# 0                    https://drmkc.jrc.ec.europa.eu/
# 1  https://drmkc.jrc.ec.europa.eu/knowledge/Gaps-...
# 2  https://drmkc.jrc.ec.europa.eu/knowledge/PROJE...
# 3  https://drmkc.jrc.ec.europa.eu/knowledge/Chall...
#
#                                                links date-of-access  \
# 0  [http://drmkc.jrc.ec.europa.eu/Overview/Events...     2021-02-18
# 0  [http://drmkc.jrc.ec.europa.eu/Overview/Events...     2021-02-18
# 1  [http://drmkc.jrc.ec.europa.eu/Overview/Events...     2021-02-18
# 2  [http://drmkc.jrc.ec.europa.eu/Overview/Events...     2021-02-18
# 3  [http://drmkc.jrc.ec.europa.eu/Overview/Events...     2021-02-18
#
#      keywords_matched                                          internals  \
# 0  publicly available  [http://drmkc.jrc.ec.europa.eu/Overview/Events...
# 0        social media  [http://drmkc.jrc.ec.europa.eu/Overview/Events...
# 1        social media  [http://drmkc.jrc.ec.europa.eu/Overview/Events...
# 2        social media  [http://drmkc.jrc.ec.europa.eu/Overview/Events...
# 3        social media  [http://drmkc.jrc.ec.europa.eu/Overview/Events...
#
#                                                 pdfs  \
# 0  [/PRIVACY_STATEMENT/Privacy_Statement_DRMKC_We...
# 0  [/PRIVACY_STATEMENT/Privacy_Statement_DRMKC_We...
# 1  [/PRIVACY_STATEMENT/Privacy_Statement_DRMKC_We...
# 2  [/PRIVACY_STATEMENT/Privacy_Statement_DRMKC_We...
# 3  [/PRIVACY_STATEMENT/Privacy_Statement_DRMKC_We...
#
#                                            externals
# 0  [https://ec.europa.eu/knowledge4policy, https:...
# 0  [https://ec.europa.eu/knowledge4policy, https:...
# 1  [https://ec.europa.eu/knowledge4policy, https:...
# 2  [https://www.securityresearch-cou.eu/thethemes...
# 3  [https://ec.europa.eu/knowledge4policy, https:...

# %%
df_kw_filter = df_kw.loc[:, ['url', 'keywords_matched']]
df_kw_filter.to_excel(os.path.join(datapath, "DRMKC-EU_urls-keywords.xlsx"), index = False)

# %%
# Pdfs

df_pdf = df.explode('pdfs')

pdfs = set(list(df_pdf['pdfs']))

pdfs
# Out:
# {'/PRIVACY_STATEMENT/Privacy_Statement_DRMKC_Website.pdf',
#  '/Portals/0/Partnerships/Loss/0-Survey/Loss Database Survey Form -France.pdf',
#  '/Portals/0/Partnerships/Loss/0-Survey/Loss Database Survey Form-Bulgaria.pdf',
#  '/Portals/0/Partnerships/Loss/1-Nov-2013/1_MINUTES Disaster Loss Data Workshop 15 November 2013.pdf',
#  '/Portals/0/Partnerships/Loss/1-Nov-2013/3_Agenda (updated).pdf',
#  '/Portals/0/Partnerships/Loss/2-Feb-014/20140213 DraftMinutesWorksho onDisasterLossDataSysteminEU_revised.pdf',
#  '/Portals/0/Partnerships/Loss/2-Feb-014/Invitation 2nd Workshop on Loss Data in EU v1.pdf',
#  '/Portals/0/Partnerships/Loss/3-May-014/20140520_IRDREULossDataWorkshop_Minutes.pdf',
#  '/Portals/0/Partnerships/Loss/3-May-014/Assessment of data quality and uncertainty in disaster loss analysis - DRAFT.pdf',
#  '/Portals/0/Partnerships/Loss/3-May-014/Joint agenda  Loss Data in EU  with IRDR meeting v2 (1)_de_1.pdf',
#  '/Portals/0/Partnerships/Loss/4-Oct-2014/Minutes_STATE OF THE ART OF DISASTER LOSS DATA RECORDING IN THE EU_23-24 October_Brussels.pdf',
#  '/inform-index/Portals/0/InfoRM/Epidemic/Incorporating epidemics risk in the INFORM global risk index.pdf',
#  '/inform-index/Portals/0/InfoRM/Publications/01 Inform 2020 ONLINE.pdf',
#  '/inform-index/Portals/0/InfoRM/Severity/INFORM Severity Index User Guide v01 October 2020.pdf',
#  '/inform-index/Portals/0/InfoRM/Severity/INFORM Severity Methodology  20201019 online.pdf',
#  '/inform-index/portals/0/InfoRM/Covid19/JRC120799_pdf.pdf',
#  '/portals/0/Evidence_Policy_School/files/01_dataviz_and_infographic_resources_and_applications.pdf',
#  '/portals/0/Evidence_Policy_School/files/02_charttypegallery.pdf',
#  '/portals/0/Evidence_Policy_School/files/2014_dolcedibucci_bee_emilia.pdf',
#  '/portals/0/Evidence_Policy_School/files/agostino_miozzo_decisions_uncertainties.pdf',
#  '/portals/0/Evidence_Policy_School/files/communicating_risk_session_media_interview.pdf',
#  '/portals/0/Evidence_Policy_School/files/evidence_for_policy_school_agenda.pdf',
#  '/portals/0/Evidence_Policy_School/files/exercise_1.pdf',
#  '/portals/0/Evidence_Policy_School/files/exercise_2.pdf',
#  '/portals/0/Evidence_Policy_School/files/fabio_castelli_risks_in_cities.pdf',
#  '/portals/0/Evidence_Policy_School/files/florence.pdf',
#  '/portals/0/Evidence_Policy_School/files/gdacs_exercises.pdf',
#  '/portals/0/Evidence_Policy_School/files/gdacsdrm_wnter_school.pdf',
#  '/portals/0/Evidence_Policy_School/files/jaroslav_mysiak_scientific_challenges.pdf',
#  '/portals/0/Evidence_Policy_School/files/karagiannis_slides_print.pdf',
#  '/portals/0/Evidence_Policy_School/files/masterclass_8_casagli.pdf',
#  '/portals/0/Evidence_Policy_School/files/masterclass_8_gigli.pdf',
#  '/portals/0/Evidence_Policy_School/files/masterclass_8_handouts.pdf',
#  '/portals/0/Evidence_Policy_School/files/okal2009.pdf',
#  '/portals/0/Evidence_Policy_School/files/paper_01_brick_et_al._winners_and_losers-communicating_the_potential_impact_of_policies.pdf',
#  '/portals/0/Evidence_Policy_School/files/risk_communication_masterclass_workshop_florence.pdf',
#  '/portals/0/Evidence_Policy_School/files/situational_awareness_and_information_management_in_emergencies.pdf',
#  '/portals/0/Evidence_Policy_School/files/slide_presentation_0.pdf',
#  '/portals/0/Evidence_Policy_School/files/slide_presentation_1.pdf',
#  '/portals/0/Evidence_Policy_School/files/slide_presentation_2.pdf',
#  '/portals/0/Evidence_Policy_School/files/slides_cascais.pdf',
#  '/portals/0/Evidence_Policy_School/files/slides_cascais_0.pdf',
#  '/portals/0/Evidence_Policy_School/files/vascovy_-_panic_at_the_border_-_staged_case_2020.pdf',
#  '/portals/0/Knowledge/NRA/JRC114650_NRARecommendations_updatedfinal_online1.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/Executive_Summary_of_Science_for_DRM_2017.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/Science_for_DRM_2017.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/annexes/annex01_acknowledgements.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/annexes/annex02_contributors-by-chapter.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/annexes/annex03_how-to-cite.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch01/ch01.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch02/ch02.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch02/ch02_intro.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch02/ch02_recommendations.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch02/ch02_references.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch02/ch02_subch0201.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch02/ch02_subch0202.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch02/ch02_subch0203.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch02/ch02_subch0204.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch02/ch02_subch0205.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s01/ch03_s01.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s01/ch03_s01_intro.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s01/ch03_s01_recommendations.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s01/ch03_s01_references.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s01/ch03_s01_subch0301.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s01/ch03_s01_subch0302.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s01/ch03_s01_subch0303.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s02/ch03_s02.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s02/ch03_s02_intro.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s02/ch03_s02_recommendations.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s02/ch03_s02_references.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s02/ch03_s02_subch0304.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s02/ch03_s02_subch0305.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s02/ch03_s02_subch0306.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s03/ch03_s03.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s03/ch03_s03_intro.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s03/ch03_s03_recommendations.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s03/ch03_s03_references.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s03/ch03_s03_subch0307.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s03/ch03_s03_subch0308.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s03/ch03_s03_subch0309.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s03/ch03_s03_subch0310.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s03/ch03_s03_subch0311.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s04/ch03_s04.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s04/ch03_s04_intro.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s04/ch03_s04_recommendations.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s04/ch03_s04_references.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s04/ch03_s04_subch0312.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s04/ch03_s04_subch0313.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch03_s04/ch03_s04_subch0314.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch04/ch04.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch04/ch04_intro.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch04/ch04_recommendations.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch04/ch04_references.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch04/ch04_subch0401.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch04/ch04_subch0402.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch04/ch04_subch0403.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch04/ch04_subch0404.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch05/ch05.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch05/ch05_intro.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch05/ch05_recommendations.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch05/ch05_references.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch05/ch05_subch0501.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch05/ch05_subch0502.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch05/ch05_subch0503.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch05/ch05_subch0504.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/ch06/ch06.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/intro/intro_drmkc.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/intro/intro_foreword.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/intro/intro_preface.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/intro/intro_short-executive-summary.pdf',
#  '/portals/0/Knowledge/ScienceforDRM/intro/intro_toc.pdf',
#  '\\Portals\\0\\Partnerships\\Loss\\5-Mar-2015/Minutes_FIFTH_EU_LOSS_WORKSHOP_30-31-March2015-ISPRA.pdf',
#  '\\Portals\\0\\Partnerships\\Loss\\5-Mar-2015\\additional_material\\2_Berg et al_Damage survey_FRIAR 2014.pdf',
#  'http://ec.europa.eu/echo/sites/echo-site/files/swd_2017_176_overview_of_risks_2.pdf',
#  'http://effis.jrc.ec.europa.eu/media/cms_page_media/40/Annual_Report_2017_final_pdf_uCckqee.pdf',
#  'http://publications.jrc.ec.europa.eu/repository/bitstream/JRC110784/ws_risk_management_capability_assessment_2018_final.pdf',
#  'https://ec.europa.eu/echo/files/about/COMM_PDF_SEC_2010_1626_F_staff_working_document_en.pdf',
#  'https://ec.europa.eu/info/sites/info/files/p4p_forest_fire_infographic.pdf',
#  nan}

# %%
# Externals

df_ext = df.explode('externals')

exts = set(list(df_ext['externals']))

exts
# Out:
# {' http://eur-lex.europa.eu/legal-content/EN/TXT/;ELX_SESSIONID=ZQnbJ1JTj0Bd5MvQyGf2gPCGx5byd16Y4Hg53FNVpvGFY0y0y1Rh!1404494154?uri=celex:32014R0661',
#  ' http://eur-lex.europa.eu/legal-content/EN/TXT/?qid=1401179579415&uri=CELEX:32013D1313',
#  ' http://eur-lex.europa.eu/legal-content/EN/TXT/?qid=1523606241167&uri=CELEX:32007L0060',
#  ' http://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX%3A32013R1300',
#  ' http://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX:01996L0082-20120813',
#  ' http://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX:31982L0501',
#  ' http://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX:32012L0018',
#  ' http://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX:52013DC0216',
#  ' https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX%3A12012A%2FTXT',
#  ' https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=celex:32008L0114',
#  'http://aristotle.ingv.it/tiki-index.php',
#  'http://dx.doi.org/10.2760/647488',
#  'http://dx.doi.org/10.2760/840421',
#  'http://dx.doi.org/10.2760/93157',
#  'http://dx.doi.org/10.2788/18330',
#  'http://dx.doi.org/10.2788/186107',
#  'http://dx.doi.org/10.2788/98653',
#  'http://ec.europa.eu/echo/sites/echo-site/files/swd_2017_176_overview_of_risks_2.pdf',
#  'http://ec.europa.eu/echo/what/civil-protection/mechanism_en',
#  'http://ec.europa.eu/geninfo/legal_notices_en.htm',
#  'http://ec.europa.eu/info/contact_en',
#  'http://effis.jrc.ec.europa.eu',
#  'http://effis.jrc.ec.europa.eu/applications',
#  'http://effis.jrc.ec.europa.eu/media/cms_page_media/40/Annual_Report_2017_final_pdf_uCckqee.pdf',
#  'http://effis.jrc.ec.europa.eu/reports-and-publications/annual-fire-reports',
#  'http://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX%3A52015XC0808(01)',
#  'http://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX:52014SC0134',
#  'http://publications.jrc.ec.europa.eu/repository/bitstream/JRC110784/ws_risk_management_capability_assessment_2018_final.pdf',
#  'http://publications.jrc.ec.europa.eu/repository/handle/JRC109146',
#  'http://publications.jrc.ec.europa.eu/repository/handle/JRC110366',
#  'http://publications.jrc.ec.europa.eu/repository/handle/JRC110489',
#  'http://publications.jrc.ec.europa.eu/repository/handle/JRC113923',
#  'http://publications.jrc.ec.europa.eu/repository/handle/JRC113937',
#  'http://publications.jrc.ec.europa.eu/repository/handle/JRC83743',
#  'http://publications.jrc.ec.europa.eu/repository/handle/JRC92290',
#  'http://publications.jrc.ec.europa.eu/repository/handle/JRC95505',
#  'http://www.exchangeofexperts.eu',
#  'http://www.fao.org/home/en',
#  'http://www.undp.org/content/undp/en/home/sustainable-development-goals.html',
#  'http://www.unep.org',
#  'http://www.unfpa.org',
#  'http://www.unwomen.org/en',
#  'https://apps.who.int/gpmb/annual_report.html',
#  'https://apps.who.int/iris/handle/10665/112667',
#  'https://batten.virginia.edu',
#  'https://covid-statistics.jrc.ec.europa.eu',
#  'https://covid-statistics.jrc.ec.europa.eu/Document',
#  'https://covid-statistics.jrc.ec.europa.eu/Home/Dashboard',
#  'https://covid-statistics.jrc.ec.europa.eu/Map',
#  'https://covid-statistics.jrc.ec.europa.eu/Measure/DashboardMeasures',
#  'https://covid-statistics.jrc.ec.europa.eu/QlikDashboard?sheet=multidim',
#  'https://dppa.un.org/en',
#  'https://ec.europa.eu/agriculture/cap-funding/funding-opportunities_en',
#  'https://ec.europa.eu/agriculture/forest/strategy',
#  'https://ec.europa.eu/echo/files/about/COMM_PDF_SEC_2010_1626_F_staff_working_document_en.pdf',
#  'https://ec.europa.eu/echo/what/civil-protection/emergency-response-coordination-centre-ercc_en',
#  'https://ec.europa.eu/echo/what/civil-protection/mechanism_en',
#  'https://ec.europa.eu/info/cookies_en',
#  'https://ec.europa.eu/info/departments/humanitarian-aid-and-civil-protection_en',
#  'https://ec.europa.eu/info/departments/joint-research-centre_en',
#  'https://ec.europa.eu/info/files/forest-fires-sparking-firesmart-policies-eu_en',
#  'https://ec.europa.eu/info/food-farming-fisheries/key-policies/common-agricultural-policy_en',
#  'https://ec.europa.eu/info/index_en',
#  'https://ec.europa.eu/info/research-and-innovation/research-area/environment/forest-fires_en',
#  'https://ec.europa.eu/info/research-and-innovation/strategy/support-policy-making/scientific-support-eu-policies/p4p_en',
#  'https://ec.europa.eu/info/resources-partners_en',
#  'https://ec.europa.eu/info/sites/info/files/p4p_forest_fire_infographic.pdf',
#  'https://ec.europa.eu/jrc/en',
#  'https://ec.europa.eu/knowledge4policy',
#  'https://ec.europa.eu/knowledge4policy/text-mining_en',
#  'https://ec.europa.eu/regional_policy/EN/funding/solidarity-fund',
#  'https://ec.europa.eu/regional_policy/en',
#  'https://ec.europa.eu/research/environment/forestfires',
#  'https://ec.europa.eu/research/p4p',
#  'https://eur-lex.europa.eu/LexUriServ/LexUriServ.do?uri=OJ:L:2013:347:0924:0947:EN:PDF',
#  'https://eur-lex.europa.eu/eli/dir/2008/114/oj',
#  'https://eur-lex.europa.eu/legal-content/EN/ALL/?uri=CELEX%3A32003H0887',
#  'https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX%3A32007L0060',
#  'https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX%3A32013D1082',
#  'https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX%3A32013L0059',
#  'https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX%3A32019D0420',
#  'https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX%3A52015XC0808%2801%29',
#  'https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX:32003L0099',
#  'https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=uriserv%3AOJ.L_.2014.219.01.0042.01.ENG',
#  'https://eur-lex.europa.eu/legal-content/en/TXT/?uri=celex%3A32012L0018',
#  'https://europa.eu/european-union/contact/social-networks_en#n:+i:4+e:1+t:+s',
#  'https://github.com/ec-jrc/COVID-19',
#  'https://media.ifrc.org/ifrc',
#  'https://publications.europa.eu/en/publication-detail/-/publication/4bc0e055-3712-11e7-a08e-01aa75ed71a1/language-en/format-PDF/source-40844781',
#  'https://publications.europa.eu/en/web/general-publications/generalconditions',
#  'https://publications.europa.eu/en/web/general-publications/publications',
#  'https://startnetwork.org',
#  'https://sustainabledevelopment.un.org/frameworks/parisagreement',
#  'https://sustainabledevelopment.un.org/frameworks/sendaiframework',
#  'https://unhabitat.org/habitat-iii',
#  'https://unhabitat.org/history-mandate-role-in-the-un-system',
#  'https://www.acaps.org',
#  'https://www.cmcc.it',
#  'https://www.gfdrr.org',
#  'https://www.google.co.uk/maps/place/JRC+-+Joint+Research+Centre/@45.6076017,8.4785455,8.67z/data=!4m2!3m1!1s0x478670adb33da5f1:0xfac7c5cea1d967ff',
#  'https://www.gov.uk/government/organisations/foreign-commonwealth-development-office',
#  'https://www.insdevforum.org',
#  'https://www.internal-displacement.org',
#  'https://www.iom.int',
#  'https://www.oecd.org',
#  'https://www.oecd.org/site/conferencecentre/gettingtotheoecd.htm',
#  'https://www.pdc.org',
#  'https://www.securityresearch-cou.eu/thethemes/Border-security-and-customs',
#  'https://www.securityresearch-cou.eu/thethemes/CBRNE-threats',
#  'https://www.securityresearch-cou.eu/thethemes/Crime-and-terrorism',
#  'https://www.securityresearch-cou.eu/thethemes/Critical-infrastructure-protection',
#  'https://www.securityresearch-cou.eu/thethemes/Disaster-Resilience-and-crisis-management',
#  'https://www.securityresearch-cou.eu/thethemes/Food-safety-and-security',
#  'https://www.securityresearch-cou.eu/thethemes/Health-threats',
#  'https://www.securityresearch-cou.eu/thethemes/Horizontal-issues',
#  'https://www.securityresearch-cou.eu/thethemes/Societal-resilience',
#  'https://www.state.gov',
#  'https://www.undp.org',
#  'https://www.undrr.org',
#  'https://www.unhcr.org',
#  'https://www.uni-muenchen.de/index.html',
#  'https://www.unicef.org',
#  'https://www.unocha.org',
#  'https://www.who.int',
#  'https://www.who.int/csr/resources/publications/HSE_GAR_ARO_2012_1/en',
#  'https://www.who.int/eios',
#  nan}

# %%
# alternate structure

df_links = df.explode('links').reset_index(drop = True).loc[:, ['url', 'links', 'date-of-access', 'keywords_matched']]
df_links['links'] = df_links['links'].fillna('""')
df_links['links'] = df_links['links'].convert_dtypes()

df_links['internal'] = df_links['links'].apply(lambda link: ("drmkc.jrc.ec" in link or "http" not in link))
df_links['pdf'] = df_links['links'].apply(lambda link: ".pdf" in link)

# %%
df_links.head()
# Out:
#                                url  \
# 0  https://drmkc.jrc.ec.europa.eu/
# 1  https://drmkc.jrc.ec.europa.eu/
# 2  https://drmkc.jrc.ec.europa.eu/
# 3  https://drmkc.jrc.ec.europa.eu/
# 4  https://drmkc.jrc.ec.europa.eu/
#
#                                            links date-of-access  \
# 0  http://drmkc.jrc.ec.europa.eu/Overview/Events     2021-02-18
# 1                               /overview/Events     2021-02-18
# 2                       /knowledge/Gaps-Explorer     2021-02-18
# 3                  /knowledge/Challenges-Sharing     2021-02-18
# 4                  http://drmkc.jrc.ec.europa.eu     2021-02-18
#
#                      keywords_matched  internal    pdf
# 0  [publicly available, social media]      True  False
# 1  [publicly available, social media]      True  False
# 2  [publicly available, social media]      True  False
# 3  [publicly available, social media]      True  False
# 4  [publicly available, social media]      True  False

# %%
df_linkskw = df_links.explode('keywords_matched').reset_index()

# %%
set(list(df_linkskw.loc[(df_linkskw['keywords_matched'] == "lidar") & (df_linkskw['internal'] == False), :]['links']))
# Out:
# {' http://eur-lex.europa.eu/legal-content/EN/TXT/;ELX_SESSIONID=ZQnbJ1JTj0Bd5MvQyGf2gPCGx5byd16Y4Hg53FNVpvGFY0y0y1Rh!1404494154?uri=celex:32014R0661',
#  ' http://eur-lex.europa.eu/legal-content/EN/TXT/?qid=1401179579415&uri=CELEX:32013D1313',
#  ' http://eur-lex.europa.eu/legal-content/EN/TXT/?qid=1523606241167&uri=CELEX:32007L0060',
#  ' http://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX%3A32013R1300',
#  ' http://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX:01996L0082-20120813',
#  ' http://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX:31982L0501',
#  ' http://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX:32012L0018',
#  ' http://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX:52013DC0216',
#  ' https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX%3A12012A%2FTXT',
#  ' https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=celex:32008L0114',
#  'http://aristotle.ingv.it/tiki-index.php',
#  'http://dx.doi.org/10.2760/647488',
#  'http://dx.doi.org/10.2760/840421',
#  'http://dx.doi.org/10.2760/93157',
#  'http://dx.doi.org/10.2788/18330',
#  'http://dx.doi.org/10.2788/186107',
#  'http://dx.doi.org/10.2788/98653',
#  'http://ec.europa.eu/echo/what/civil-protection/mechanism_en',
#  'http://ec.europa.eu/geninfo/legal_notices_en.htm',
#  'http://ec.europa.eu/info/contact_en',
#  'http://effis.jrc.ec.europa.eu',
#  'http://effis.jrc.ec.europa.eu/applications',
#  'http://effis.jrc.ec.europa.eu/media/cms_page_media/40/Annual_Report_2017_final_pdf_uCckqee.pdf',
#  'http://effis.jrc.ec.europa.eu/reports-and-publications/annual-fire-reports',
#  'http://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX%3A52015XC0808(01)',
#  'http://publications.jrc.ec.europa.eu/repository/handle/JRC109146',
#  'http://publications.jrc.ec.europa.eu/repository/handle/JRC110366',
#  'http://publications.jrc.ec.europa.eu/repository/handle/JRC110489',
#  'http://publications.jrc.ec.europa.eu/repository/handle/JRC83743',
#  'http://publications.jrc.ec.europa.eu/repository/handle/JRC92290',
#  'http://publications.jrc.ec.europa.eu/repository/handle/JRC95505',
#  'http://www.exchangeofexperts.eu',
#  'http://www.undp.org/content/undp/en/home/sustainable-development-goals.html',
#  'https://ec.europa.eu/agriculture/cap-funding/funding-opportunities_en',
#  'https://ec.europa.eu/agriculture/forest/strategy',
#  'https://ec.europa.eu/echo/what/civil-protection/emergency-response-coordination-centre-ercc_en',
#  'https://ec.europa.eu/echo/what/civil-protection/mechanism_en',
#  'https://ec.europa.eu/info/cookies_en',
#  'https://ec.europa.eu/info/departments/joint-research-centre_en',
#  'https://ec.europa.eu/info/files/forest-fires-sparking-firesmart-policies-eu_en',
#  'https://ec.europa.eu/info/food-farming-fisheries/key-policies/common-agricultural-policy_en',
#  'https://ec.europa.eu/info/index_en',
#  'https://ec.europa.eu/info/research-and-innovation/research-area/environment/forest-fires_en',
#  'https://ec.europa.eu/info/resources-partners_en',
#  'https://ec.europa.eu/info/sites/info/files/p4p_forest_fire_infographic.pdf',
#  'https://ec.europa.eu/jrc/en',
#  'https://ec.europa.eu/knowledge4policy',
#  'https://ec.europa.eu/regional_policy/EN/funding/solidarity-fund',
#  'https://ec.europa.eu/regional_policy/en',
#  'https://ec.europa.eu/research/environment/forestfires',
#  'https://ec.europa.eu/research/p4p',
#  'https://eur-lex.europa.eu/LexUriServ/LexUriServ.do?uri=OJ:L:2013:347:0924:0947:EN:PDF',
#  'https://europa.eu/european-union/contact/social-networks_en#n:+i:4+e:1+t:+s',
#  'https://sustainabledevelopment.un.org/frameworks/parisagreement',
#  'https://sustainabledevelopment.un.org/frameworks/sendaiframework',
#  'https://unhabitat.org/habitat-iii',
#  'https://unhabitat.org/history-mandate-role-in-the-un-system'}
